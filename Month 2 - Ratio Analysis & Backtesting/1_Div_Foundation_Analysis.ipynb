# %% [markdown]
# # Dividend & Company Foundation Analysis
# This project is to study and analyze what makes a company potentially good for investment. There are a few financial metrics/ratios where its value can be analyzed that tells if the company is healthy or growing. The companies that meet the requirements from certain ranges of these values can be used as an indicative are specified below:
#
# ### Foundational Ratios
# 1) Earnings Per Share  >= 10%
#
#
# 2) Price to Earnings - <= 10%
#
#
# 3) Operating Margins - >= 10%
#
#
# 4) Return of Equity - >= 20%
#
#
# 5) Free Cash Flow - >= 0
#
#
# ### Dividend Ratios
# 1) Annual Dividend Yield - >= 2%
#
#
# 2) Payout Ratio - >= 25% && <= 75%
#
#
# The project first reads the list of stock symbols (provided by Bursa Marketplace) that can be used as URL or reference to retrieve these metrics/ratios. By means of yfinance API and intelligent web scraping, these values can be easily retrieved by demonstrating an intelligent looping process that iterates the list of stock symbols and running the processes accordingly.

# %%
# import libraries
from datetime import datetime
from pandas_datareader import data as pdr
import yfinance as yf
import pandas as pd
import time
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import random
import warnings
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 10)

# %% [markdown]
# # Part I: Retrieving the Dividend & Foundation Ratios (yfinance API & Web Scraping)
#
# ## Reading the List of Stock Symbols
# The stocks.csv is read to gather the symbols as idenfication for web scraping and API argument to get its respective values.

# %%
df = pd.read_csv('exports/stocks.csv')
df
# Out:
#                              stock_name stock_code
# 0     7-ELEVEN MALAYSIA HOLDINGS BERHAD       5250
# 1          ABF MALAYSIA BOND INDEX FUND     0800EA
# 2                    ABLE GLOBAL BERHAD       7167
# 3                      ABLEGROUP BERHAD       7086
# 4                     ABM FUJIYA BERHAD       5198
# ...                                 ...        ...
# 1008               YKGI HOLDINGS BERHAD       7020
# 1009                YLI HOLDINGS BERHAD       7014
# 1010                YNH PROPERTY BERHAD       3158
# 1011                    YONG TAI BERHAD       7066
# 1012       YOONG ONN CORPORATION BERHAD       5159
#
# [1013 rows x 2 columns]

# %% [markdown]
# ## .KL is added to support yfinance argument format to reference the stock symbol

# %%
# Add ".KL" to each value in the 'stock_code' column
testdf = df['stock_code'].apply(lambda x: x + ".KL")
testdf
# Out:
# 0         5250.KL
# 1       0800EA.KL
# 2         7167.KL
# 3         7086.KL
# 4         5198.KL
#           ...
# 1008      7020.KL
# 1009      7014.KL
# 1010      3158.KL
# 1011      7066.KL
# 1012      5159.KL
# Name: stock_code, Length: 1013, dtype: object

# %%
# Put it into a list called stock_code
stock_code = list(testdf)
stock_code
# Out:
# ['5250.KL',
#  '0800EA.KL',
#  '7167.KL',
#  '7086.KL',
#  '5198.KL',
#  '03028.KL',
#  '7131.KL',
#  '0218.KL',
#  '0122.KL',
#  '1481.KL',
#  '5281.KL',
#  '9148.KL',
#  '7191.KL',
#  '7146.KL',
#  '0181.KL',
#  '6599.KL',
#  '5139.KL',
#  '5185.KL',
#  '7145.KL',
#  '0258.KL',
#  '7315.KL',
#  '7078.KL',
#  '0209.KL',
#  '5238.KL',
#  '2658.KL',
#  '7609.KL',
#  '5116.KL',
#  '5115.KL',
#  '0118.KL',
#  '5401.KL',
#  '9059.KL',
#  '5042.KL',
#  '0272.KL',
#  '5297.KL',
#  '5230.KL',
#  '5167.KL',
#  '4359.KL',
#  '7079.KL',
#  '7100.KL',
#  '03043.KL',
#  '0005.KL',
#  '1368.KL',
#  '5148.KL',
#  '0256.KL',
#  '7137.KL',
#  '7227.KL',
#  '4588.KL',
#  '03017.KL',
#  '7091.KL',
#  '0257.KL',
#  '5005.KL',
#  '2593.KL',
#  '2089.KL',
#  '7133.KL',
#  '0247.KL',
#  '5200.KL',
#  '5110.KL',
#  '7757.KL',
#  '5292.KL',
#  '7250.KL',
#  '6963.KL',
#  '5243.KL',
#  '4995.KL',
#  '0273.KL',
#  '0069.KL',
#  '0120.KL',
#  '0097.KL',
#  '7070.KL',
#  '0232.KL',
#  '0838EA.KL',
#  '0066.KL',
#  '5162.KL',
#  '5142.KL',
#  '0102.KL',
#  '7203.KL',
#  '5016.KL',
#  '7226.KL',
#  '3565.KL',
#  '9679.KL',
#  '0197.KL',
#  '7231.KL',
#  '0271.KL',
#  '5246.KL',
#  '5009.KL',
#  '0162.KL',
#  '0008.KL',
#  '6378.KL',
#  '7050.KL',
#  '7025.KL',
#  '4243.KL',
#  '5156.KL',
#  '5267.KL',
#  '7121.KL',
#  '0165.KL',
#  '0140.KL',
#  '0017.KL',
#  ...]

# %% [markdown]
# ## Getting the Dividend and Financial Ratios of the listed companies
# The code below demonstrates retrieving the important dividend and financial ratios of the listed companies from their symbols. The values are being sourced from Yahoo Finance and Bursa Marketplace to ensure data integrity and consistency. Dividend Yield, Payout Ratio and Operating Margins are retrieved through Yahoo Finance with yfinance API. Price to Earnings, Return of Equity and Operating Margins are retrieved from Bursa Marketplace through a complex method of web scraping.

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(20)

# funtion to get link
def get_link(stock_code):
    
    url='https://www.bursamarketplace.com/index.php'
    driver.get(url)
    
    # Clicking the Search Button
    s= driver.find_ele ent(By.XPATH,'//*[@id="newnav-mobileSearch"]')
    driver.execute_script("arguments[0].click();",s)
    
    # Inputting the Stock Code in the Search Bar
    driver.find_element(By.XPATH, '//*[@id="newnav-search-input"]').send_keys(stock_code)
    
    # Getting the Link in the appeared Search Results
    lnks = driver.find_element(By.ID,'url')
    links=lnks.get_attribute('href')
    return links

# %%
results_df = []
new_list = []

# Define the columns you want to retrieve
columns_to_fetch = ["dividendYield", "payoutRatio", "operatingMargins"]

# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=['Ticker'] + columns_to_fetch)

# Loop through each ticker in the CSV
for ticker_symbol in stock_code:
    try:
        # Create a Ticker object using yfinance
        ticker = yf.Ticker(ticker_symbol)

        # Get the info for the ticker
        ticker_info = ticker.info

        # Extract the desired columns from the ticker info
        row_data = {
            'Ticker': ticker_symbol,
        }

        for column in columns_to_fetch:
            if column in ticker_info:
                row_data[column] = ticker_info[column]
            else:
                row_data[column] = None
        print(row_data)
        
        # Get the cashflow data
        cashflow_df = ticker.cashflow
        
        # Extract the latest Free Cash Flow value dynamically
        latest_date = cashflow_df.columns[0]  # Get the last column (latest date)
        row_data['CF'] = cashflow_df.loc['Free Cash Flow', latest_date]
        
        url=get_link(ticker_symbol[:-3]) # Exclude ".KL for Bursa Marketplace Search Function"
        driver.get(url)
        content = driver.page_source
        soup = bs(content)
        
        time.sleep(5)
        
        try:
            stock_PE = driver.find_element(By.XPATH, "//div[text()='P/E']/following-sibling::div")
            row_data['P/E'] = stock_PE.text
            stock_ROE = driver.find_element(By.XPATH, "//div[text()='ROE']/following-sibling::div")
            row_data['ROE'] = stock_ROE.text
            stock_EPS = driver.find_element(By.XPATH, "//div[text()='EPS']/following-sibling::div")
            row_data['EPS'] = stock_EPS.text
        except:
             print('stock code :'+s+' cannot scrape values')

        # Append the data as a row to the results DataFrame
        results_df = pd.concat([results_df, pd.DataFrame([row_data])], ignore_index=True)
        

    except Exception as e:
        print(f"Error fetching data for {ticker_symbol}: {str(e)}")
        new_list.append(ticker_symbol)
# Out:
# {'Ticker': '5250.KL', 'dividendYield': 0.0271, 'payoutRatio': 1.0385, 'operatingMargins': 0.048189998}
# {'Ticker': '0800EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0800EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '7167.KL', 'dividendYield': 0.0465, 'payoutRatio': 0.4039, 'operatingMargins': 0.08492}
# {'Ticker': '7086.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.04338}
# {'Ticker': '5198.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.0195}
# {'Ticker': '03028.KL', 'dividendYield': 0.056599997, 'payoutRatio': 99.0, 'operatingMargins': -5e-05}
# {'Ticker': '7131.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.09486}
# {'Ticker': '0218.KL', 'dividendYield': 0.0089, 'payoutRatio': 0.1418, 'operatingMargins': 0.02849}
# {'Ticker': '0122.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -2.6105301}
# {'Ticker': '1481.KL', 'dividendYield': 0.0070999996, 'payoutRatio': None, 'operatingMargins': -0.03102}
# {'Ticker': '5281.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.00699}
# {'Ticker': '9148.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.06138}
# {'Ticker': '7191.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.25435}
# {'Ticker': '7146.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.16245002}
# {'Ticker': '0181.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.30313}
# {'Ticker': '6599.KL', 'dividendYield': 0.0364, 'payoutRatio': 0.5391, 'operatingMargins': 0.07073}
# {'Ticker': '5139.KL', 'dividendYield': 0.040599998, 'payoutRatio': 0.3254, 'operatingMargins': 0.36981}
# {'Ticker': '5185.KL', 'dividendYield': 0.0577, 'payoutRatio': 16.0953, 'operatingMargins': 0.19718}
# {'Ticker': '7145.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.20955999}
# {'Ticker': '0258.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.27194}
# {'Ticker': '7315.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -2.05483}
# {'Ticker': '7078.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.13971}
# {'Ticker': '0209.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.14484}
# {'Ticker': '5238.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -23.75049}
# {'Ticker': '2658.KL', 'dividendYield': 0.0058999998, 'payoutRatio': 0.1275, 'operatingMargins': 0.05416}
# {'Ticker': '7609.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.17275}
# {'Ticker': '5116.KL', 'dividendYield': 0.0608, 'payoutRatio': 1.1202999, 'operatingMargins': 0.87135005}
# {'Ticker': '5115.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.04319}
# {'Ticker': '2674.KL', 'dividendYield': 0.0313, 'payoutRatio': 0.0722, 'operatingMargins': 0.093339995}
# {'Ticker': '0079.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.11795}
# {'Ticker': '2488.KL', 'dividendYield': 0.0592, 'payoutRatio': 0.5528, 'operatingMargins': 0.50092}
# {'Ticker': '1163.KL', 'dividendYield': 0.0733, 'payoutRatio': 0.78839993, 'operatingMargins': 0.16384001}
# {'Ticker': '03051.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': -2.4063299}
# {'Ticker': '5269.KL', 'dividendYield': 0.0717, 'payoutRatio': 0.26680002, 'operatingMargins': 0.65529996}
# {'Ticker': '5127.KL', 'dividendYield': 0.0396, 'payoutRatio': 2.7393, 'operatingMargins': 0.56323004}
# {'Ticker': '5293.KL', 'dividendYield': 0.0201, 'payoutRatio': 0.1618, 'operatingMargins': 0.13588001}
# {'Ticker': '5307.KL', 'dividendYield': 0.056700002, 'payoutRatio': 0.5187, 'operatingMargins': 0.83195996}
# {'Ticker': '5120.KL', 'dividendYield': 0.0806, 'payoutRatio': 1.1688, 'operatingMargins': 0.50039}
# {'Ticker': '03011.KL', 'dividendYield': 0.0186, 'payoutRatio': 0.354, 'operatingMargins': 0.059959996}
# {'Ticker': '1015.KL', 'dividendYield': 0.063, 'payoutRatio': 0.3547, 'operatingMargins': 0.53021}
# {'Ticker': '7031.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.06786}
# {'Ticker': '6351.KL', 'dividendYield': 0.0377, 'payoutRatio': 0.4159, 'operatingMargins': 0.06783}
# {'Ticker': '7083.KL', 'dividendYield': 0.0127, 'payoutRatio': 0.0845, 'operatingMargins': 0.18518}
# {'Ticker': '0048.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.059970003}
# {'Ticker': '4758.KL', 'dividendYield': 0.0084, 'payoutRatio': 0.0, 'operatingMargins': 0.05672}
# {'Ticker': '0226.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.11063}
# {'Ticker': '6556.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.09122}
# {'Ticker': '5082.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.16415001}
# {'Ticker': '5568.KL', 'dividendYield': None, 'payoutRatio': 1.3652999, 'operatingMargins': 0.11193}
# {'Ticker': '5088.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.17357999}
# {'Ticker': '7090.KL', 'dividendYield': 0.02, 'payoutRatio': 0.2603, 'operatingMargins': 0.104770005}
# {'Ticker': '5015.KL', 'dividendYield': 0.068, 'payoutRatio': 0.9537, 'operatingMargins': 0.02705}
# {'Ticker': '6432.KL', 'dividendYield': 0.065799996, 'payoutRatio': 0.5759, 'operatingMargins': 0.15283}
# {'Ticker': '0119.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.08951}
# {'Ticker': '7214.KL', 'dividendYield': 0.05, 'payoutRatio': 0.32930002, 'operatingMargins': 0.03187}
# {'Ticker': '7181.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.052160002}
# {'Ticker': '7007.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.080340005}
# {'Ticker': '0038.KL', 'dividendYield': 0.0025, 'payoutRatio': 0.0, 'operatingMargins': -0.05704}
# {'Ticker': '0068.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.27676}
# {'Ticker': '7722.KL', 'dividendYield': 0.0377, 'payoutRatio': 0.5168, 'operatingMargins': 0.07669}
# {'Ticker': '7129.KL', 'dividendYield': 0.0182, 'payoutRatio': 0.0995, 'operatingMargins': 0.15819}
# {'Ticker': '0159.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.29343}
# {'Ticker': '0105.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.081590004}
# {'Ticker': '4057.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.111619994}
# {'Ticker': '7162.KL', 'dividendYield': 0.0172, 'payoutRatio': 0.15720001, 'operatingMargins': 0.0624}
# {'Ticker': '7054.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.43106}
# {'Ticker': '03032.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.29201}
# {'Ticker': '6399.KL', 'dividendYield': 0.087, 'payoutRatio': 1.0, 'operatingMargins': 0.09624}
# {'Ticker': '0072.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.36588}
# {'Ticker': '8176.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.42238998}
# {'Ticker': '7048.KL', 'dividendYield': 0.0143, 'payoutRatio': 0.45509997, 'operatingMargins': 0.096190006}
# {'Ticker': '5130.KL', 'dividendYield': 0.0507, 'payoutRatio': 0.9215, 'operatingMargins': 0.80606}
# {'Ticker': '7099.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.093389995}
# {'Ticker': '5302.KL', 'dividendYield': 0.0174, 'payoutRatio': 0.36169997, 'operatingMargins': 0.10578}
# {'Ticker': '03037.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.05752}
# {'Ticker': '8885.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.00495}
# {'Ticker': '5204.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.10458}
# {'Ticker': '7579.KL', 'dividendYield': 0.036, 'payoutRatio': 0.36830002, 'operatingMargins': 0.02829}
# {'Ticker': '6888.KL', 'dividendYield': 0.059499998, 'payoutRatio': None, 'operatingMargins': 0.0851}
# {'Ticker': '5106.KL', 'dividendYield': 0.0446, 'payoutRatio': 0.9333, 'operatingMargins': 0.70637}
# {'Ticker': '7120.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.16976}
# {'Ticker': '2305.KL', 'dividendYield': 0.0271, 'payoutRatio': 0.36029997, 'operatingMargins': 0.41175}
# {'Ticker': '5021.KL', 'dividendYield': 0.0253, 'payoutRatio': 0.1439, 'operatingMargins': 0.041350003}
# {'Ticker': '7005.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.038629998}
# {'Ticker': '03012.KL', 'dividendYield': 0.0075, 'payoutRatio': 0.205, 'operatingMargins': 0.15489}
# {'Ticker': '0098.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.04087}
# {'Ticker': '5258.KL', 'dividendYield': 0.0318, 'payoutRatio': 0.5789, 'operatingMargins': 0.33368}
# {'Ticker': '7251.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.025109999}
# {'Ticker': '1899.KL', 'dividendYield': 0.0545, 'payoutRatio': 0.65480006, 'operatingMargins': 0.0908}
# {'Ticker': '6602.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.21484}
# {'Ticker': '0187.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.09997}
# {'Ticker': '5190.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.53279996}
# {'Ticker': '3239.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.20743}
# {'Ticker': '3395.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.06306}
# {'Ticker': '5196.KL', 'dividendYield': 0.0467, 'payoutRatio': 1.854, 'operatingMargins': 0.16540001}
# {'Ticker': '4219.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.063769996}
# {'Ticker': '5248.KL', 'dividendYield': 0.080299996, 'payoutRatio': 0.47529998, 'operatingMargins': 0.10130999}
# {'Ticker': '9814.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.056929998}
# {'Ticker': '7668.KL', 'dividendYield': 0.0392, 'payoutRatio': 2.046, 'operatingMargins': 0.10014}
# {'Ticker': '0263.KL', 'dividendYield': 0.033, 'payoutRatio': 0.1385, 'operatingMargins': 0.12893}
# {'Ticker': '6173.KL', 'dividendYield': 0.0148, 'payoutRatio': None, 'operatingMargins': 0.03807}
# {'Ticker': '5932.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.77088}
# {'Ticker': '0195.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.08903}
# {'Ticker': '6998.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.15018}
# {'Ticker': '5032.KL', 'dividendYield': 0.0238, 'payoutRatio': 0.5822, 'operatingMargins': 0.27339}
# {'Ticker': '0179.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.59511}
# {'Ticker': '5069.KL', 'dividendYield': 0.0027, 'payoutRatio': 0.2583, 'operatingMargins': 0.014520001}
# {'Ticker': '0168.KL', 'dividendYield': 0.019, 'payoutRatio': 0.4781, 'operatingMargins': 0.06599}
# {'Ticker': '9288.KL', 'dividendYield': 0.044699997, 'payoutRatio': 0.2839, 'operatingMargins': 0.20153}
# {'Ticker': '7036.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.56104}
# {'Ticker': '8133.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.022880001}
# {'Ticker': '2771.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 2771.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '5254.KL', 'dividendYield': 0.0274, 'payoutRatio': 2.0951, 'operatingMargins': 0.0598}
# {'Ticker': '6297.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.00821}
# {'Ticker': '5100.KL', 'dividendYield': 0.048800003, 'payoutRatio': 0.5345, 'operatingMargins': 0.06459}
# {'Ticker': '9938.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.02881}
# {'Ticker': '0011.KL', 'dividendYield': 0.0296, 'payoutRatio': 0.2712, 'operatingMargins': 0.43935}
# {'Ticker': '4162.KL', 'dividendYield': 0.0808, 'payoutRatio': 1.0673001, 'operatingMargins': 0.32758}
# {'Ticker': '7221.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.083579995}
# {'Ticker': '7188.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -2.23523}
# {'Ticker': '5210.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.42474}
# {'Ticker': '1818.KL', 'dividendYield': 0.044499997, 'payoutRatio': 0.9233, 'operatingMargins': 0.52355}
# {'Ticker': '03042.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.29995}
# {'Ticker': '2828.KL', 'dividendYield': 0.0484, 'payoutRatio': 0.1935, 'operatingMargins': 0.03546}
# {'Ticker': '7174.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.08585}
# {'Ticker': '0191.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.01556}
# {'Ticker': '2852.KL', 'dividendYield': 0.026300002, 'payoutRatio': 0.1319, 'operatingMargins': 0.01249}
# {'Ticker': '7128.KL', 'dividendYield': None, 'payoutRatio': 0.1319, 'operatingMargins': 0.0546}
# {'Ticker': '5105.KL', 'dividendYield': 0.0149, 'payoutRatio': 0.314, 'operatingMargins': 0.036059998}
# {'Ticker': '5311.KL', 'dividendYield': 0.0047, 'payoutRatio': 0.0, 'operatingMargins': 0.099659994}
# {'Ticker': '5099.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.045840003}
# {'Ticker': '5180.KL', 'dividendYield': 0.0725, 'payoutRatio': 2.4235, 'operatingMargins': 0.47257}
# {'Ticker': '0163.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.62741}
# {'Ticker': '5257.KL', 'dividendYield': 0.0215, 'payoutRatio': 0.0, 'operatingMargins': 0.11339}
# {'Ticker': '03016.KL', 'dividendYield': 0.045500003, 'payoutRatio': 0.2161, 'operatingMargins': 0.29161}
# {'Ticker': '2836.KL', 'dividendYield': 0.044, 'payoutRatio': 0.85870004, 'operatingMargins': 0.17198}
# {'Ticker': '03048.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.24235001}
# {'Ticker': '0173.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.14602}
# {'Ticker': '7076.KL', 'dividendYield': 0.0364, 'payoutRatio': None, 'operatingMargins': -0.051119998}
# {'Ticker': '03053.KL', 'dividendYield': 0.0294, 'payoutRatio': 2.506, 'operatingMargins': 0.14716}
# {'Ticker': '7035.KL', 'dividendYield': 0.0435, 'payoutRatio': 0.2969, 'operatingMargins': 0.059949998}
# {'Ticker': '03024.KL', 'dividendYield': 0.0013, 'payoutRatio': 0.0183, 'operatingMargins': 0.17295}
# {'Ticker': '0238.KL', 'dividendYield': 0.015800001, 'payoutRatio': 0.38459998, 'operatingMargins': 0.13647}
# {'Ticker': '0243.KL', 'dividendYield': 0.0292, 'payoutRatio': 0.3493, 'operatingMargins': 0.25768}
# {'Ticker': '5195.KL', 'dividendYield': 0.0319, 'payoutRatio': 0.9146, 'operatingMargins': 0.0764}
# {'Ticker': '8052.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.076630004}
# {'Ticker': '8982.KL', 'dividendYield': 0.0432, 'payoutRatio': 0.8368, 'operatingMargins': 0.07998}
# {'Ticker': '7209.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.11614}
# {'Ticker': '5273.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.027479999}
# {'Ticker': '7187.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.047280002}
# {'Ticker': '1929.KL', 'dividendYield': 0.0209, 'payoutRatio': 0.23110001, 'operatingMargins': 0.27754}
# {'Ticker': '5007.KL', 'dividendYield': 0.0104, 'payoutRatio': 0.6192, 'operatingMargins': 0.10031}
# {'Ticker': '5188.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -2.2241}
# {'Ticker': '5797.KL', 'dividendYield': 0.0269, 'payoutRatio': None, 'operatingMargins': -0.058029998}
# {'Ticker': '7016.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.00945}
# {'Ticker': '1023.KL', 'dividendYield': 0.0645, 'payoutRatio': 0.44919997, 'operatingMargins': 0.48251}
# {'Ticker': '7245.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.14536999}
# {'Ticker': '5104.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.0066299997}
# {'Ticker': '7117.KL', 'dividendYield': 0.0375, 'payoutRatio': 0.45450002, 'operatingMargins': 0.03243}
# {'Ticker': '7202.KL', 'dividendYield': 0.156, 'payoutRatio': 1.375, 'operatingMargins': 0.2223}
# {'Ticker': '7154.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.20896}
# {'Ticker': '03001.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.00765}
# {'Ticker': '7018.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.040949997}
# {'Ticker': '7986.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.50861}
# {'Ticker': '0246.KL', 'dividendYield': 0.026199998, 'payoutRatio': 0.0, 'operatingMargins': 0.12793}
# {'Ticker': '5071.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.25636}
# {'Ticker': '2127.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.22635001}
# {'Ticker': '7195.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.121759996}
# {'Ticker': '5037.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.18215}
# {'Ticker': '8044.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.12179}
# {'Ticker': '8435.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.03769}
# {'Ticker': '0240.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.107609995}
# {'Ticker': '0261.KL', 'dividendYield': 0.0256, 'payoutRatio': 0.4611, 'operatingMargins': 0.08026}
# {'Ticker': '5738.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.49984002}
# {'Ticker': '5049.KL', 'dividendYield': 0.0545, 'payoutRatio': 1.3672, 'operatingMargins': 0.09764}
# {'Ticker': '6718.KL', 'dividendYield': 0.036, 'payoutRatio': 0.7463, 'operatingMargins': 0.12831001}
# {'Ticker': '8591.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.02466}
# {'Ticker': '5094.KL', 'dividendYield': 0.024600001, 'payoutRatio': 0.6865, 'operatingMargins': -0.00834}
# {'Ticker': '7165.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.86891}
# {'Ticker': '5301.KL', 'dividendYield': 0.015700001, 'payoutRatio': 0.6197, 'operatingMargins': 0.34569}
# {'Ticker': '0051.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.23846}
# {'Ticker': '9423.KL', 'dividendYield': 0.0221, 'payoutRatio': 0.152, 'operatingMargins': 0.08984999}
# {'Ticker': '7157.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.20583001}
# {'Ticker': '5184.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.18202999}
# {'Ticker': '7204.KL', 'dividendYield': 0.0038, 'payoutRatio': 0.2717, 'operatingMargins': 0.124230005}
# {'Ticker': '4456.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.120620005}
# {'Ticker': '3484.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 3484.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0400GB.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0400GB.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '5276.KL', 'dividendYield': 0.0482, 'payoutRatio': 0.4651, 'operatingMargins': 0.13689}
# {'Ticker': '8338.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.60778}
# {'Ticker': '5216.KL', 'dividendYield': 0.051599998, 'payoutRatio': 0.6826, 'operatingMargins': 0.31861}
# {'Ticker': '5141.KL', 'dividendYield': 0.0311, 'payoutRatio': 0.3043, 'operatingMargins': 0.23113}
# {'Ticker': '5132.KL', 'dividendYield': 0.036, 'payoutRatio': 0.4747, 'operatingMargins': 0.08189}
# {'Ticker': '7212.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.19493}
# {'Ticker': '5165.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.02794}
# {'Ticker': '0152.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.36922002}
# {'Ticker': '7277.KL', 'dividendYield': 0.0222, 'payoutRatio': 0.3825, 'operatingMargins': 0.087349996}
# {'Ticker': '6947.KL', 'dividendYield': 0.0293, 'payoutRatio': 1.3630999, 'operatingMargins': 0.45075}
# {'Ticker': '0029.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.28294}
# {'Ticker': '0131.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.13313}
# {'Ticker': '7528.KL', 'dividendYield': 0.014199999, 'payoutRatio': 0.18059999, 'operatingMargins': 0.16653}
# {'Ticker': '5908.KL', 'dividendYield': 0.033099998, 'payoutRatio': 0.4084, 'operatingMargins': 0.02528}
# {'Ticker': '7114.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.00496}
# {'Ticker': '5835.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 5835.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '5265.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.4577}
# {'Ticker': '7169.KL', 'dividendYield': 0.039, 'payoutRatio': 0.45520002, 'operatingMargins': 0.02905}
# {'Ticker': '0205.KL', 'dividendYield': 0.012200001, 'payoutRatio': 1.0, 'operatingMargins': 0.054330003}
# {'Ticker': '7198.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.10775}
# {'Ticker': '1619.KL', 'dividendYield': 0.0139999995, 'payoutRatio': 0.2083, 'operatingMargins': 0.04276}
# {'Ticker': '0269.KL', 'dividendYield': 0.018099999, 'payoutRatio': 0.0, 'operatingMargins': 0.16906}
# {'Ticker': '03055.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': 0.0}
# Error fetching data for 03055.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '7233.KL', 'dividendYield': 0.0324, 'payoutRatio': 1.0252, 'operatingMargins': 0.48789}
# {'Ticker': '7148.KL', 'dividendYield': 0.019199999, 'payoutRatio': 0.3199, 'operatingMargins': 0.13239999}
# {'Ticker': '3948.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.026500002}
# {'Ticker': '3026.KL', 'dividendYield': 0.0222, 'payoutRatio': 0.86660004, 'operatingMargins': 0.02974}
# {'Ticker': '03046.KL', 'dividendYield': 0.026700001, 'payoutRatio': 0.9756, 'operatingMargins': 0.30707002}
# {'Ticker': '5259.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.21451999}
# {'Ticker': '0154.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.02648}
# {'Ticker': '3417.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.01179}
# {'Ticker': '0267.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.31081}
# {'Ticker': '2143.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.111770004}
# {'Ticker': '8206.KL', 'dividendYield': 0.0556, 'payoutRatio': 0.78370005, 'operatingMargins': 0.15183}
# {'Ticker': '5283.KL', 'dividendYield': 0.90410006, 'payoutRatio': 0.0, 'operatingMargins': -0.17193002}
# {'Ticker': '0059.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.20291}
# {'Ticker': '3557.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 1.03194}
# {'Ticker': '0239.KL', 'dividendYield': 0.014199999, 'payoutRatio': 0.2941, 'operatingMargins': 0.1616}
# {'Ticker': '0227.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.22207001}
# {'Ticker': '5253.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.02473}
# {'Ticker': '0255.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.09016}
# {'Ticker': '5036.KL', 'dividendYield': 0.034, 'payoutRatio': 0.8663, 'operatingMargins': 0.06431}
# {'Ticker': '7471.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.02642}
# {'Ticker': '0107.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.9071499}
# {'Ticker': '0064.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.09116}
# {'Ticker': '8907.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.04443}
# {'Ticker': '5208.KL', 'dividendYield': 0.036199998, 'payoutRatio': 0.8865, 'operatingMargins': 0.031070001}
# {'Ticker': '8877.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.20718001}
# {'Ticker': '9016.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.37369}
# {'Ticker': '5228.KL', 'dividendYield': 0.052199997, 'payoutRatio': 0.76559997, 'operatingMargins': 0.40015}
# {'Ticker': '0090.KL', 'dividendYield': 0.0381, 'payoutRatio': 0.335, 'operatingMargins': 0.15053001}
# {'Ticker': '9091.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.15032}
# {'Ticker': '6076.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.34441003}
# {'Ticker': '03025.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.07068}
# {'Ticker': '7149.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.047399998}
# {'Ticker': '5056.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.02159}
# {'Ticker': '8613.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.07799}
# {'Ticker': '7217.KL', 'dividendYield': 0.025, 'payoutRatio': None, 'operatingMargins': -0.059169997}
# {'Ticker': '7773.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.040960003}
# {'Ticker': '03021.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.6274}
# {'Ticker': '0100.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.08776}
# {'Ticker': '5081.KL', 'dividendYield': 0.0328, 'payoutRatio': None, 'operatingMargins': -0.00386}
# {'Ticker': '6815.KL', 'dividendYield': 0.016900001, 'payoutRatio': 0.102, 'operatingMargins': 0.16649}
# {'Ticker': '7208.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.10977}
# {'Ticker': '7094.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.19171}
# {'Ticker': '0174.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.08432}
# {'Ticker': '5101.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': -0.04666}
# {'Ticker': '0190.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.014520001}
# {'Ticker': '5205.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.01672}
# {'Ticker': '7249.KL', 'dividendYield': None, 'payoutRatio': 1.0417, 'operatingMargins': 0.083680004}
# {'Ticker': '0065.KL', 'dividendYield': 0.025999999, 'payoutRatio': 0.65790004, 'operatingMargins': 0.37002}
# {'Ticker': '2984.KL', 'dividendYield': 0.02, 'payoutRatio': 0.3547, 'operatingMargins': 0.02479}
# {'Ticker': '7047.KL', 'dividendYield': 0.0339, 'payoutRatio': 0.6135, 'operatingMargins': -0.1091}
# {'Ticker': '5029.KL', 'dividendYield': 0.048600003, 'payoutRatio': 0.95739996, 'operatingMargins': 0.15781}
# {'Ticker': '6041.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.27617}
# {'Ticker': '5306.KL', 'dividendYield': 0.0083, 'payoutRatio': 0.48419997, 'operatingMargins': 0.0834}
# {'Ticker': '0084.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.02232}
# {'Ticker': '7229.KL', 'dividendYield': 0.0219, 'payoutRatio': 0.4143, 'operatingMargins': 0.13268}
# {'Ticker': '2755.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.027579999}
# {'Ticker': '8605.KL', 'dividendYield': 0.0113, 'payoutRatio': 0.0, 'operatingMargins': 0.16399999}
# {'Ticker': '5222.KL', 'dividendYield': 0.1079, 'payoutRatio': 0.9388, 'operatingMargins': 0.039419997}
# {'Ticker': '6939.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.12206}
# {'Ticker': '0149.KL', 'dividendYield': 0.0278, 'payoutRatio': 0.1358, 'operatingMargins': 0.21441}
# {'Ticker': '03026.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# {'Ticker': '3107.KL', 'dividendYield': 0.070199996, 'payoutRatio': 1.1013, 'operatingMargins': 0.11971}
# {'Ticker': '0150.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.48451}
# {'Ticker': '9318.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.18604}
# {'Ticker': '0231.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.03337}
# {'Ticker': '7210.KL', 'dividendYield': 0.1026, 'payoutRatio': 0.4768, 'operatingMargins': 0.07114}
# {'Ticker': '0116.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.05126}
# {'Ticker': '5197.KL', 'dividendYield': 0.1254, 'payoutRatio': 0.8804, 'operatingMargins': 0.06689}
# {'Ticker': '0157.KL', 'dividendYield': 0.0385, 'payoutRatio': 0.36189997, 'operatingMargins': 0.19497}
# {'Ticker': '9172.KL', 'dividendYield': 0.0758, 'payoutRatio': 0.60830003, 'operatingMargins': 0.11582}
# {'Ticker': '5277.KL', 'dividendYield': 0.037, 'payoutRatio': 0.7143, 'operatingMargins': 0.12158}
# {'Ticker': '3689.KL', 'dividendYield': 0.021300001, 'payoutRatio': 0.4425, 'operatingMargins': 0.12667}
# {'Ticker': '0128.KL', 'dividendYield': 0.013300001, 'payoutRatio': 0.5505, 'operatingMargins': 0.32016}
# {'Ticker': '9377.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.31410998}
# {'Ticker': '0820EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0820EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '7676.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.24468}
# {'Ticker': '7184.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.17337}
# {'Ticker': '5226.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.06331}
# {'Ticker': '9261.KL', 'dividendYield': 0.020599999, 'payoutRatio': None, 'operatingMargins': -0.04143}
# {'Ticker': '0206.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.044699997}
# {'Ticker': '5398.KL', 'dividendYield': 0.0271, 'payoutRatio': 0.39580002, 'operatingMargins': 0.09212}
# {'Ticker': '5209.KL', 'dividendYield': 0.047199998, 'payoutRatio': 0.77019995, 'operatingMargins': 0.062080003}
# {'Ticker': '0198.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.01894}
# {'Ticker': '0078.KL', 'dividendYield': 0.0083, 'payoutRatio': None, 'operatingMargins': -0.06046}
# {'Ticker': '0104.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.27736}
# {'Ticker': '3182.KL', 'dividendYield': 0.036, 'payoutRatio': 2.8319001, 'operatingMargins': 0.18715}
# {'Ticker': '4715.KL', 'dividendYield': 0.0598, 'payoutRatio': None, 'operatingMargins': 0.12991}
# {'Ticker': '2291.KL', 'dividendYield': 0.0296, 'payoutRatio': 0.7068, 'operatingMargins': 0.11963}
# {'Ticker': '3204.KL', 'dividendYield': 0.0396, 'payoutRatio': None, 'operatingMargins': 0.072}
# {'Ticker': '7197.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.0531}
# {'Ticker': '0039.KL', 'dividendYield': 0.02, 'payoutRatio': 0.1184, 'operatingMargins': 0.35604}
# {'Ticker': '0021.KL', 'dividendYield': 0.0311, 'payoutRatio': 0.95059997, 'operatingMargins': 0.10323}
# {'Ticker': '7192.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.29802}
# Error fetching data for 7192.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '1147.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.061}
# {'Ticker': '5220.KL', 'dividendYield': 0.030299999, 'payoutRatio': 0.3839, 'operatingMargins': 0.06267}
# {'Ticker': '7022.KL', 'dividendYield': 0.019199999, 'payoutRatio': 0.5703, 'operatingMargins': 0.25541002}
# {'Ticker': '5020.KL', 'dividendYield': 0.033299997, 'payoutRatio': 0.3788, 'operatingMargins': 0.18955}
# {'Ticker': '7382.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.18255}
# {'Ticker': '5649.KL', 'dividendYield': 0.089499995, 'payoutRatio': 0.314, 'operatingMargins': 0.20741}
# {'Ticker': '2135.KL', 'dividendYield': 0.0286, 'payoutRatio': None, 'operatingMargins': -0.75664}
# {'Ticker': '03029.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.14661}
# {'Ticker': '5592.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.2707}
# {'Ticker': '0208.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.19708}
# {'Ticker': '0074.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.32422}
# {'Ticker': '0082.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.068909995}
# {'Ticker': '0136.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.10935}
# {'Ticker': '9962.KL', 'dividendYield': 0.05, 'payoutRatio': 0.1587, 'operatingMargins': 0.24164}
# {'Ticker': '5102.KL', 'dividendYield': None, 'payoutRatio': 0.2307, 'operatingMargins': 0.03968}
# {'Ticker': '3247.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.01688}
# {'Ticker': '1503.KL', 'dividendYield': 0.0274, 'payoutRatio': 0.3143, 'operatingMargins': 0.16163}
# {'Ticker': '0237.KL', 'dividendYield': 0.0277, 'payoutRatio': 0.3052, 'operatingMargins': 0.03809}
# {'Ticker': '7253.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.60846}
# {'Ticker': '3034.KL', 'dividendYield': 0.0682, 'payoutRatio': 0.5435, 'operatingMargins': 0.11662}
# {'Ticker': '5138.KL', 'dividendYield': 0.0452, 'payoutRatio': 1.2861999, 'operatingMargins': 0.17056}
# {'Ticker': '2062.KL', 'dividendYield': 0.047399998, 'payoutRatio': 0.1158, 'operatingMargins': 0.17875999}
# {'Ticker': '7501.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.02938}
# {'Ticker': '5008.KL', 'dividendYield': 0.059699997, 'payoutRatio': 0.2845, 'operatingMargins': 0.044949997}
# {'Ticker': '5168.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': -0.02072}
# {'Ticker': '0060.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.17929001}
# {'Ticker': '5187.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.6865401}
# {'Ticker': '7105.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.1722}
# {'Ticker': '3255.KL', 'dividendYield': 0.056700002, 'payoutRatio': 1.0072, 'operatingMargins': 0.20485}
# {'Ticker': '5028.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.07872}
# {'Ticker': '5121.KL', 'dividendYield': 0.1322, 'payoutRatio': 0.5373, 'operatingMargins': 0.4729}
# {'Ticker': '0175.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.24063998}
# {'Ticker': '4324.KL', 'dividendYield': 0.0307, 'payoutRatio': None, 'operatingMargins': -0.092659995}
# {'Ticker': '5095.KL', 'dividendYield': 0.033800002, 'payoutRatio': None, 'operatingMargins': -0.0071799997}
# {'Ticker': '5151.KL', 'dividendYield': 0.013099999, 'payoutRatio': 0.2857, 'operatingMargins': 0.12505001}
# {'Ticker': '7803.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.36308998}
# {'Ticker': '0161.KL', 'dividendYield': 0.0506, 'payoutRatio': 0.0, 'operatingMargins': 0.1041}
# {'Ticker': '5136.KL', 'dividendYield': None, 'payoutRatio': 16.6667, 'operatingMargins': 0.022160001}
# {'Ticker': '3298.KL', 'dividendYield': 0.0423, 'payoutRatio': 1.2121, 'operatingMargins': 0.11545999}
# {'Ticker': '0160.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.09}
# {'Ticker': '5072.KL', 'dividendYield': 0.023, 'payoutRatio': 1.3889, 'operatingMargins': 0.0026800002}
# {'Ticker': '5199.KL', 'dividendYield': 0.026500002, 'payoutRatio': 0.1039, 'operatingMargins': 0.32027}
# {'Ticker': '8443.KL', 'dividendYield': 0.02, 'payoutRatio': 0.24129999, 'operatingMargins': 0.20040001}
# {'Ticker': '0188.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.24326}
# {'Ticker': '5169.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.16574}
# {'Ticker': '9601.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.00382}
# {'Ticker': '5160.KL', 'dividendYield': 0.0525, 'payoutRatio': 0.317, 'operatingMargins': 0.19743}
# {'Ticker': '5819.KL', 'dividendYield': 0.030299999, 'payoutRatio': 0.31129998, 'operatingMargins': 0.60952}
# {'Ticker': '5274.KL', 'dividendYield': 0.0322, 'payoutRatio': 0.90050006, 'operatingMargins': 0.37335998}
# {'Ticker': '1082.KL', 'dividendYield': 0.0271, 'payoutRatio': 0.1917, 'operatingMargins': 0.60326}
# {'Ticker': '3301.KL', 'dividendYield': 0.0641, 'payoutRatio': 0.5884, 'operatingMargins': 0.12049}
# {'Ticker': '0041.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -6.27775}
# {'Ticker': '5291.KL', 'dividendYield': 0.0165, 'payoutRatio': 0.3953, 'operatingMargins': 0.10090999}
# {'Ticker': '0228.KL', 'dividendYield': 0.039, 'payoutRatio': 0.6261, 'operatingMargins': 0.16497}
# {'Ticker': '0185.KL', 'dividendYield': 0.0115, 'payoutRatio': 0.2507, 'operatingMargins': 0.1389}
# {'Ticker': '5062.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.13548}
# {'Ticker': '7013.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.0032}
# {'Ticker': '5000.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.097729996}
# {'Ticker': '5024.KL', 'dividendYield': 0.056700002, 'payoutRatio': 0.9238, 'operatingMargins': 0.13161999}
# {'Ticker': '8478.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.07802}
# {'Ticker': '4251.KL', 'dividendYield': 0.0074, 'payoutRatio': 0.0, 'operatingMargins': 0.042179998}
# {'Ticker': '5084.KL', 'dividendYield': 0.0342, 'payoutRatio': 0.2339, 'operatingMargins': 0.22752}
# {'Ticker': '5108.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 5108.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '5255.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.02636}
# {'Ticker': '9113.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.18548}
# {'Ticker': '03038.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.09243}
# {'Ticker': '03030.KL', 'dividendYield': 0.01, 'payoutRatio': 0.3125, 'operatingMargins': 0.39186}
# {'Ticker': '9687.KL', 'dividendYield': 0.0049, 'payoutRatio': 0.0, 'operatingMargins': 0.10929}
# {'Ticker': '0023.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.01745}
# {'Ticker': '5606.KL', 'dividendYield': 0.0626, 'payoutRatio': 0.192, 'operatingMargins': 0.4675}
# {'Ticker': '5299.KL', 'dividendYield': 0.0653, 'payoutRatio': 1.3256, 'operatingMargins': 0.5003}
# {'Ticker': '5227.KL', 'dividendYield': 0.056399997, 'payoutRatio': 0.90139997, 'operatingMargins': 0.66589}
# {'Ticker': '5225.KL', 'dividendYield': 0.0179, 'payoutRatio': 0.28959998, 'operatingMargins': 0.15074}
# {'Ticker': '0401GA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0401GA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '3336.KL', 'dividendYield': 0.0323, 'payoutRatio': 0.936, 'operatingMargins': 0.1904}
# {'Ticker': '5614.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.04295}
# {'Ticker': '7222.KL', 'dividendYield': 0.0062, 'payoutRatio': 5.6452003, 'operatingMargins': 0.05263}
# {'Ticker': '7243.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.06961}
# {'Ticker': '0166.KL', 'dividendYield': 0.0276, 'payoutRatio': 0.9989, 'operatingMargins': 0.21278}
# {'Ticker': '2607.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.70537}
# {'Ticker': '9393.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.17374}
# {'Ticker': '0253.KL', 'dividendYield': 0.028499998, 'payoutRatio': 0.44189999, 'operatingMargins': 0.2321}
# {'Ticker': '0265.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.19258}
# {'Ticker': '7240.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.66269994}
# {'Ticker': '5178.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.32209}
# {'Ticker': '5295.KL', 'dividendYield': 0.0674, 'payoutRatio': 1.3274001, 'operatingMargins': 0.14006}
# {'Ticker': '0147.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.03895}
# {'Ticker': '6262.KL', 'dividendYield': 0.072, 'payoutRatio': 1.6515, 'operatingMargins': 0.23758}
# {'Ticker': '3379.KL', 'dividendYield': 0.028399998, 'payoutRatio': 0.0765, 'operatingMargins': -0.02323}
# {'Ticker': '0192.KL', 'dividendYield': 0.0481, 'payoutRatio': 0.2874, 'operatingMargins': 0.03918}
# {'Ticker': '1961.KL', 'dividendYield': 0.0251, 'payoutRatio': 0.77989995, 'operatingMargins': 0.14066}
# {'Ticker': '5249.KL', 'dividendYield': 0.0301, 'payoutRatio': 0.1519, 'operatingMargins': 0.49219}
# {'Ticker': '5107.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.057979997}
# {'Ticker': '7183.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.046329997}
# {'Ticker': '8834.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -9.08772}
# {'Ticker': '0010.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.09423}
# {'Ticker': '1589.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.025039999}
# {'Ticker': '5309.KL', 'dividendYield': 0.0044, 'payoutRatio': 0.14840001, 'operatingMargins': 0.55474}
# {'Ticker': '5175.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 4.78272}
# {'Ticker': '7043.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.73998}
# {'Ticker': '7223.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.32584998}
# {'Ticker': '0024.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.0477}
# {'Ticker': '4723.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.55253}
# {'Ticker': '8648.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.05356}
# {'Ticker': '4383.KL', 'dividendYield': 0.0364, 'payoutRatio': 0.3091, 'operatingMargins': 0.24341999}
# {'Ticker': '7152.KL', 'dividendYield': 0.083900005, 'payoutRatio': 0.939, 'operatingMargins': 0.12673001}
# {'Ticker': '0058.KL', 'dividendYield': 0.0375, 'payoutRatio': 0.2689, 'operatingMargins': 0.63102}
# {'Ticker': '5161.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.2917}
# {'Ticker': '5673.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.56167}
# Error fetching data for 8931.KL: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/8931.KL?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# {'Ticker': '0146.KL', 'dividendYield': 0.0092, 'payoutRatio': 0.70419997, 'operatingMargins': 0.22025}
# {'Ticker': '0127.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.06718}
# {'Ticker': '8923.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -3.12467}
# {'Ticker': '03040.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.10658}
# {'Ticker': '6769.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.34248}
# {'Ticker': '7096.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.68461}
# {'Ticker': '3441.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.47741}
# {'Ticker': '5192.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.01212}
# {'Ticker': '8672.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.04127}
# {'Ticker': '0170.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.18569}
# {'Ticker': '5247.KL', 'dividendYield': 0.0179, 'payoutRatio': 0.0, 'operatingMargins': 0.042150002}
# {'Ticker': '0054.KL', 'dividendYield': 0.02, 'payoutRatio': 0.33330002, 'operatingMargins': 0.041050002}
# {'Ticker': '7216.KL', 'dividendYield': 0.02, 'payoutRatio': 0.3987, 'operatingMargins': 0.08331}
# {'Ticker': '3476.KL', 'dividendYield': 0.033299997, 'payoutRatio': 0.1511, 'operatingMargins': 0.080570005}
# {'Ticker': '7199.KL', 'dividendYield': 0.014400001, 'payoutRatio': 0.0732, 'operatingMargins': 0.08748}
# {'Ticker': '0193.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.05187}
# {'Ticker': '0151.KL', 'dividendYield': 0.02, 'payoutRatio': 0.2352, 'operatingMargins': 0.06334}
# {'Ticker': '7323.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.28598}
# {'Ticker': '6483.KL', 'dividendYield': 0.0686, 'payoutRatio': 0.939, 'operatingMargins': 0.0802}
# {'Ticker': '0835EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0835EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0834EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0834EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '7161.KL', 'dividendYield': 0.0615, 'payoutRatio': 0.639, 'operatingMargins': 0.12997}
# {'Ticker': '7077.KL', 'dividendYield': 0.0366, 'payoutRatio': 0.2991, 'operatingMargins': 0.31572}
# {'Ticker': '9334.KL', 'dividendYield': 0.0099, 'payoutRatio': None, 'operatingMargins': -0.01372}
# {'Ticker': '0036.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.48658}
# {'Ticker': '0143.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.3183}
# {'Ticker': '6203.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.04853}
# {'Ticker': '7062.KL', 'dividendYield': 0.0305, 'payoutRatio': 0.4042, 'operatingMargins': 0.02643}
# {'Ticker': '6211.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.04156}
# {'Ticker': '5371.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.08365}
# {'Ticker': '0210.KL', 'dividendYield': 0.0343, 'payoutRatio': 0.0, 'operatingMargins': 0.03115}
# {'Ticker': '5027.KL', 'dividendYield': 0.0538, 'payoutRatio': 0.6536, 'operatingMargins': 0.14021}
# {'Ticker': '0180.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.05207}
# {'Ticker': '5171.KL', 'dividendYield': 0.0121, 'payoutRatio': None, 'operatingMargins': 0.01234}
# {'Ticker': '5280.KL', 'dividendYield': 0.0787, 'payoutRatio': 0.62560004, 'operatingMargins': 0.61091}
# {'Ticker': '9466.KL', 'dividendYield': 0.042600002, 'payoutRatio': 0.8264, 'operatingMargins': 0.10606}
# {'Ticker': '5235SS.KL', 'dividendYield': 0.051799998, 'payoutRatio': 0.8503, 'operatingMargins': 0.64485}
# {'Ticker': '2453.KL', 'dividendYield': 0.0026, 'payoutRatio': None, 'operatingMargins': 0.25507}
# {'Ticker': '7164.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.040700004}
# {'Ticker': '5035.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.0011}
# {'Ticker': '6971.KL', 'dividendYield': 0.016, 'payoutRatio': 0.24530001, 'operatingMargins': 0.12222}
# {'Ticker': '7017.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.04601}
# {'Ticker': '0111.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.00593}
# {'Ticker': '4847.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.07121}
# {'Ticker': '7153.KL', 'dividendYield': 0.109799996, 'payoutRatio': None, 'operatingMargins': -0.024719998}
# {'Ticker': '0002.KL', 'dividendYield': 0.056399997, 'payoutRatio': 0.5628, 'operatingMargins': 0.27362}
# {'Ticker': '5878.KL', 'dividendYield': 0.028099999, 'payoutRatio': 0.5567, 'operatingMargins': 0.14045}
# {'Ticker': '9121.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.01799}
# {'Ticker': '1996.KL', 'dividendYield': 0.0348, 'payoutRatio': 0.97089994, 'operatingMargins': 0.06467}
# {'Ticker': '0176.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.08509}
# {'Ticker': '5038.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.36013}
# {'Ticker': '2445.KL', 'dividendYield': 0.0467, 'payoutRatio': 0.91410005, 'operatingMargins': 0.08753}
# {'Ticker': '6874.KL', 'dividendYield': 0.0357, 'payoutRatio': 0.2467, 'operatingMargins': 0.05659}
# {'Ticker': '2186.KL', 'dividendYield': 0.0075, 'payoutRatio': None, 'operatingMargins': 0.77191}
# {'Ticker': '6491.KL', 'dividendYield': 0.05, 'payoutRatio': 0.48470002, 'operatingMargins': 0.14837}
# {'Ticker': '7033.KL', 'dividendYield': 0.0339, 'payoutRatio': 0.4594, 'operatingMargins': 0.30547002}
# {'Ticker': '9083.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.015149999}
# {'Ticker': '5310.KL', 'dividendYield': 0.0152, 'payoutRatio': 0.0, 'operatingMargins': 0.06881}
# {'Ticker': '5843.KL', 'dividendYield': 0.0986, 'payoutRatio': 0.3744, 'operatingMargins': 0.04484}
# {'Ticker': '8362.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.0191}
# {'Ticker': '0268.KL', 'dividendYield': 0.0111, 'payoutRatio': 0.0, 'operatingMargins': 0.15596}
# {'Ticker': '7179.KL', 'dividendYield': 0.0465, 'payoutRatio': 0.4096, 'operatingMargins': 0.27547002}
# ...
# {'Ticker': '0211.KL', 'dividendYield': 0.0513, 'payoutRatio': None, 'operatingMargins': 0.00772}
# {'Ticker': '0221.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.014939999}
# {'Ticker': '2054.KL', 'dividendYield': 0.0463, 'payoutRatio': None, 'operatingMargins': -0.030299999}
# {'Ticker': '5289.KL', 'dividendYield': 0.0112, 'payoutRatio': 0.2778, 'operatingMargins': 0.06487}
# {'Ticker': '2739.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.05243}
# {'Ticker': '0132.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.13504}
# {'Ticker': '7439.KL', 'dividendYield': 0.0296, 'payoutRatio': 0.0349, 'operatingMargins': 0.09588}
# {'Ticker': '7200.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.06813}
# {'Ticker': '0230.KL', 'dividendYield': None, 'payoutRatio': 0.1967, 'operatingMargins': 0.15228}
# {'Ticker': '4863.KL', 'dividendYield': 0.0347, 'payoutRatio': 0.4783, 'operatingMargins': 0.15841}
# {'Ticker': '5347.KL', 'dividendYield': 0.043899998, 'payoutRatio': 0.8777, 'operatingMargins': 0.11038999}
# {'Ticker': '9369.KL', 'dividendYield': 0.0403, 'payoutRatio': 0.24110001, 'operatingMargins': 0.12359}
# {'Ticker': '7252.KL', 'dividendYield': 0.0185, 'payoutRatio': 0.100200005, 'operatingMargins': 0.08562}
# {'Ticker': '0089.KL', 'dividendYield': 0.0353, 'payoutRatio': 0.11359999, 'operatingMargins': 0.34331}
# {'Ticker': '8702.KL', 'dividendYield': 0.2644, 'payoutRatio': None, 'operatingMargins': 0.024419999}
# {'Ticker': '0145.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.15464}
# {'Ticker': '5112.KL', 'dividendYield': 0.0561, 'payoutRatio': 0.7335, 'operatingMargins': 0.1282}
# {'Ticker': '9075.KL', 'dividendYield': 0.0234, 'payoutRatio': 0.4225, 'operatingMargins': 0.02638}
# {'Ticker': '7034.KL', 'dividendYield': 0.0309, 'payoutRatio': 0.2742, 'operatingMargins': 0.08595}
# {'Ticker': '0012.KL', 'dividendYield': 0.0309, 'payoutRatio': 0.4386, 'operatingMargins': 0.04928}
# {'Ticker': '7889.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.116359994}
# {'Ticker': '7374.KL', 'dividendYield': 0.066700004, 'payoutRatio': None, 'operatingMargins': 0.01958}
# {'Ticker': '7854.KL', 'dividendYield': None, 'payoutRatio': 0.44439998, 'operatingMargins': -0.04009}
# {'Ticker': '5031.KL', 'dividendYield': 0.0228, 'payoutRatio': 0.7555, 'operatingMargins': 0.26783}
# {'Ticker': '8397.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.13174}
# {'Ticker': '5239.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.0512}
# {'Ticker': '0101.KL', 'dividendYield': 0.0069, 'payoutRatio': 0.1228, 'operatingMargins': 0.15100001}
# {'Ticker': '7230.KL', 'dividendYield': 0.0348, 'payoutRatio': 0.1041, 'operatingMargins': 0.08999}
# {'Ticker': '7285.KL', 'dividendYield': 0.0256, 'payoutRatio': 0.0, 'operatingMargins': 1.36214}
# {'Ticker': '5010.KL', 'dividendYield': 0.0794, 'payoutRatio': 0.78190005, 'operatingMargins': 0.055689998}
# {'Ticker': '5268.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.6310099}
# Error fetching data for 5268.KL: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="url"]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6963F7892+54818]
# 	(No symbol) [0x00007FF696366AC2]
# 	(No symbol) [0x00007FF69621DA3B]
# 	(No symbol) [0x00007FF69625E4FC]
# 	(No symbol) [0x00007FF69625E67C]
# 	(No symbol) [0x00007FF696299627]
# 	(No symbol) [0x00007FF69627EAEF]
# 	(No symbol) [0x00007FF6962975A2]
# 	(No symbol) [0x00007FF69627E883]
# 	(No symbol) [0x00007FF696253691]
# 	(No symbol) [0x00007FF6962548D4]
# 	GetHandleVerifier [0x00007FF69675B992+3610402]
# 	GetHandleVerifier [0x00007FF6967B1860+3962352]
# 	GetHandleVerifier [0x00007FF6967A9D4F+3930847]
# 	GetHandleVerifier [0x00007FF696493646+693206]
# 	(No symbol) [0x00007FF696371628]
# 	(No symbol) [0x00007FF69636D934]
# 	(No symbol) [0x00007FF69636DA62]
# 	(No symbol) [0x00007FF69635E113]
# 	BaseThreadInitThunk [0x00007FFD44FD7344+20]
# 	RtlUserThreadStart [0x00007FFD46F226B1+33]
#
# {'Ticker': '7113.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.19344}
# {'Ticker': '03013.KL', 'dividendYield': 0.013300001, 'payoutRatio': 0.8621, 'operatingMargins': 0.18240999}
# {'Ticker': '5111.KL', 'dividendYield': 0.012999999, 'payoutRatio': None, 'operatingMargins': 0.4075}
# {'Ticker': '7173.KL', 'dividendYield': 0.0106, 'payoutRatio': 2.5109, 'operatingMargins': 0.02219}
# {'Ticker': '7176.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.01633}
# {'Ticker': '0836EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0836EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0833EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0833EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0832EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0832EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0837EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0837EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0831EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0831EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0830EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0830EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0829EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0829EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0829EB.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0829EB.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0828EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0828EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '7218.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.020399999}
# {'Ticker': '5054.KL', 'dividendYield': 0.0308, 'payoutRatio': 0.1012, 'operatingMargins': 0.053600002}
# {'Ticker': '0199.KL', 'dividendYield': 0.040900003, 'payoutRatio': 0.35709998, 'operatingMargins': 0.051880002}
# {'Ticker': '0118.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.93588996}
# {'Ticker': '5401.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.15841}
# {'Ticker': '9059.KL', 'dividendYield': 0.10609999, 'payoutRatio': 0.42290002, 'operatingMargins': 0.09345999}
# {'Ticker': '5042.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.21424}
# {'Ticker': '0272.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.24485001}
# {'Ticker': '5297.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.08212}
# {'Ticker': '5230.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.03559}
# {'Ticker': '5167.KL', 'dividendYield': 0.0070999996, 'payoutRatio': 0.2017, 'operatingMargins': 0.05583}
# {'Ticker': '4359.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.27412}
# {'Ticker': '7079.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.08303001}
# {'Ticker': '7100.KL', 'dividendYield': 0.0954, 'payoutRatio': 0.8723, 'operatingMargins': 0.59421}
# {'Ticker': '03043.KL', 'dividendYield': 0.0111, 'payoutRatio': 0.0, 'operatingMargins': 0.09263}
# {'Ticker': '0005.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.01477}
# {'Ticker': '1368.KL', 'dividendYield': 0.0374, 'payoutRatio': 0.6803, 'operatingMargins': 0.0252}
# {'Ticker': '5148.KL', 'dividendYield': 0.0058, 'payoutRatio': 0.3125, 'operatingMargins': 0.20813999}
# {'Ticker': '0256.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': 0.24781999}
# {'Ticker': '7137.KL', 'dividendYield': 0.031600002, 'payoutRatio': 0.6682, 'operatingMargins': 0.20416}
# {'Ticker': '7227.KL', 'dividendYield': 0.0319, 'payoutRatio': 0.4702, 'operatingMargins': 0.047909997}
# {'Ticker': '4588.KL', 'dividendYield': 0.0298, 'payoutRatio': 0.2575, 'operatingMargins': 0.047259998}
# {'Ticker': '03017.KL', 'dividendYield': None, 'payoutRatio': 0.2887, 'operatingMargins': -0.21448}
# {'Ticker': '7091.KL', 'dividendYield': 0.0323, 'payoutRatio': 0.221, 'operatingMargins': 0.15654999}
# {'Ticker': '0257.KL', 'dividendYield': 0.0222, 'payoutRatio': 0.0, 'operatingMargins': 0.059699997}
# {'Ticker': '5005.KL', 'dividendYield': 0.0247, 'payoutRatio': 0.8282, 'operatingMargins': 0.11063}
# {'Ticker': '2593.KL', 'dividendYield': 0.0275, 'payoutRatio': 0.6339, 'operatingMargins': 0.09942}
# {'Ticker': '2089.KL', 'dividendYield': 0.103599995, 'payoutRatio': 0.7263, 'operatingMargins': 0.39354}
# {'Ticker': '7133.KL', 'dividendYield': 0.0537, 'payoutRatio': 0.35119998, 'operatingMargins': 0.22241}
# {'Ticker': '0247.KL', 'dividendYield': 0.0107, 'payoutRatio': 2.05, 'operatingMargins': 0.02096}
# {'Ticker': '5200.KL', 'dividendYield': 0.1775, 'payoutRatio': 0.9497, 'operatingMargins': 0.12185001}
# {'Ticker': '5110.KL', 'dividendYield': 0.0727, 'payoutRatio': 0.9977, 'operatingMargins': 0.69475}
# {'Ticker': '7757.KL', 'dividendYield': 0.034, 'payoutRatio': 0.4566, 'operatingMargins': 0.1107}
# {'Ticker': '5292.KL', 'dividendYield': None, 'payoutRatio': 0.3854, 'operatingMargins': 0.25070998}
# {'Ticker': '7250.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.12461001}
# {'Ticker': '6963.KL', 'dividendYield': 0.0201, 'payoutRatio': 0.5181, 'operatingMargins': 0.059520002}
# {'Ticker': '5243.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.090299994}
# {'Ticker': '4995.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.0025600002}
# {'Ticker': '0273.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.11391}
# {'Ticker': '0069.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.92061996}
# {'Ticker': '0120.KL', 'dividendYield': 0.05, 'payoutRatio': 0.404, 'operatingMargins': 0.14795999}
# {'Ticker': '0097.KL', 'dividendYield': 0.0116, 'payoutRatio': 0.3335, 'operatingMargins': 0.49327}
# {'Ticker': '7070.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.12197}
# {'Ticker': '0232.KL', 'dividendYield': 0.0294, 'payoutRatio': 0.2616, 'operatingMargins': 0.11338}
# {'Ticker': '0838EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0838EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0066.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.6403999}
# {'Ticker': '5162.KL', 'dividendYield': 0.0463, 'payoutRatio': 0.3388, 'operatingMargins': 0.02903}
# {'Ticker': '5142.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.07273}
# {'Ticker': '0102.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.46122003}
# {'Ticker': '7203.KL', 'dividendYield': 0.0221, 'payoutRatio': 0.45450002, 'operatingMargins': 0.018509999}
# {'Ticker': '5016.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.00851}
# {'Ticker': '7226.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.19951001}
# {'Ticker': '3565.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.050640002}
# {'Ticker': '9679.KL', 'dividendYield': 0.0089, 'payoutRatio': 0.15720001, 'operatingMargins': 0.052810002}
# {'Ticker': '0197.KL', 'dividendYield': None, 'payoutRatio': 0.2083, 'operatingMargins': 0.32948002}
# {'Ticker': '7231.KL', 'dividendYield': 0.0591, 'payoutRatio': 0.6882, 'operatingMargins': 0.27228}
# {'Ticker': '0271.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.03467}
# {'Ticker': '5246.KL', 'dividendYield': 0.0495, 'payoutRatio': 0.6412, 'operatingMargins': 0.45724}
# {'Ticker': '5009.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.11545999}
# {'Ticker': '0162.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.17165}
# {'Ticker': '0008.KL', 'dividendYield': 0.0423, 'payoutRatio': 0.5017, 'operatingMargins': 0.09389}
# {'Ticker': '6378.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.108669996}
# {'Ticker': '7050.KL', 'dividendYield': 0.010299999, 'payoutRatio': None, 'operatingMargins': 0.023570001}
# {'Ticker': '7025.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.29737}
# {'Ticker': '4243.KL', 'dividendYield': 0.0319, 'payoutRatio': None, 'operatingMargins': -0.05229}
# {'Ticker': '5156.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.04698}
# {'Ticker': '5267.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.07871}
# {'Ticker': '7121.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.09563}
# {'Ticker': '0165.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.100200005}
# {'Ticker': '0140.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.43026}
# {'Ticker': '0017.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.15989}
# {'Ticker': '7003.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.24834}
# {'Ticker': '7178.KL', 'dividendYield': 0.0311, 'payoutRatio': 0.26479998, 'operatingMargins': 0.15466}
# {'Ticker': '5048.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.65843004}
# {'Ticker': '0025.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.03178}
# {'Ticker': '5300.KL', 'dividendYield': 0.0353, 'payoutRatio': 0.4156, 'operatingMargins': 0.08068}
# {'Ticker': '0248.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.02465}
# {'Ticker': '0086.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.03703}
# {'Ticker': '7293.KL', 'dividendYield': 0.007900001, 'payoutRatio': 0.18290001, 'operatingMargins': 0.20139}
# {'Ticker': '7020.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.0053399997}
# {'Ticker': '7014.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.08203}
# {'Ticker': '3158.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': 0.23087999}
# {'Ticker': '7066.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.01471}
# {'Ticker': '5159.KL', 'dividendYield': 0.0425, 'payoutRatio': 0.2354, 'operatingMargins': 0.19364999}
#        Ticker dividendYield payoutRatio operatingMargins           CF     P/E  \
# 0     5250.KL        0.0271      1.0385          0.04819  353993000.0   38.19
# 1     7167.KL        0.0465      0.4039          0.08492 -143040391.0   12.02
# 2     7086.KL          None         0.0          0.04338     810389.0  108.11
# 3     5198.KL          None         0.0           0.0195  -45692900.0       -
# 4    03028.KL        0.0566        99.0         -0.00005   -5502239.0       -
# ..        ...           ...         ...              ...          ...     ...
# 975   7020.KL          None         0.0         -0.00534    3660971.0       -
# 976   7014.KL          None         0.0          0.08203   -8095000.0    7.74
# 977   3158.KL          None         0.0          0.23088   24588648.0       -
# 978   7066.KL          None         0.0         -0.01471  -48212179.0       -
# 979   5159.KL        0.0425      0.2354          0.19365   29487000.0    6.50
#
#          ROE     EPS
# 0     51.103   0.060
# 1      8.475   0.109
# 2      0.674   0.000
# 3     -3.447  -0.012
# 4     -0.253   0.000
# ..       ...     ...
# 975  -11.211  -0.013
# 976    3.636   0.033
# 977   -2.587  -0.005
# 978   -8.419  -0.060
# 979   13.078   0.240
#
# [980 rows x 8 columns]

# %%
# Save the results to a CSV file
results_df.to_csv('exports/stock_info.csv', index=False)

# Display the results DataFrame
print(results_df)

# %% [markdown]
# ## There seems to be Symbols that have faced some errors in retrieving data
# These symbols are separated in another list variable showed below (and saved to a separate CSV)

# %%
dflist = pd.DataFrame(new_list, columns=['stock_code'])

# Specify the file path where you want to save the CSV file
csv_file_path = 'exports/errorprices.csv'

# Use the to_csv() method to export the DataFrame to a CSV file
dflist.to_csv(csv_file_path, index=False)  # Set index=False to exclude the DataFrame index from the CSV

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to exports/errorprices.csv

# %%
new_list
# Out:
# ['0800EA.KL',
#  '2771.KL',
#  '3484.KL',
#  '0400GB.KL',
#  '5835.KL',
#  '03055.KL',
#  '0820EA.KL',
#  '7192.KL',
#  '5108.KL',
#  '0401GA.KL',
#  '8931.KL',
#  '0835EA.KL',
#  '0834EA.KL',
#  '6645.KL',
#  '0821EA.KL',
#  '0827EA.KL',
#  '0824EA.KL',
#  '0825EA.KL',
#  '0822EA.KL',
#  '0823EA.KL',
#  '5270.KL',
#  '7158.KL',
#  '5268.KL',
#  '0836EA.KL',
#  '0833EA.KL',
#  '0832EA.KL',
#  '0837EA.KL',
#  '0831EA.KL',
#  '0830EA.KL',
#  '0829EA.KL',
#  '0829EB.KL',
#  '0828EA.KL',
#  '0838EA.KL']

# %% [markdown]
# ## Another loop was carried out that iterates the error symbols in an attempt to retrieve the values again
# Just to ensure if some errors are temporary, the list of error symbols are iterated with the repeated process. The same results occur.

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(20)

# funtion to get link
def get_link2(stock_code):
    
    url='https://www.bursamarketplace.com/index.php'
    driver.get(url)
    
    #click search button
    s= driver.find_element(By.XPATH,'//*[@id="newnav-mobileSearch"]')
    driver.execute_script("arguments[0].click();",s)
    
    # input code
    driver.find_element(By.XPATH, '//*[@id="newnav-search-input"]').send_keys(stock_code)
    
    # get the link
    lnks = driver.find_element(By.ID,'url')
    links=lnks.get_attribute('href')
    return links

# Define the columns you want to retrieve
columns_to_fetch = ["dividendYield", "payoutRatio", "operatingMargins"]

# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=['Ticker'] + columns_to_fetch)

# Loop through each ticker in the CSV
for ticker_symbol in new_list:
    try:
        # Create a Ticker object using yfinance
        ticker = yf.Ticker(ticker_symbol)

        # Get the info for the ticker
        ticker_info = ticker.info

        # Extract the desired columns from the ticker info
        row_data = {
            'Ticker': ticker_symbol,
        }

        for column in columns_to_fetch:
            if column in ticker_info:
                row_data[column] = ticker_info[column]
            else:
                row_data[column] = None
        print(row_data)
        
        # Get the cashflow data
        cashflow_df = ticker.cashflow
        
        # Extract the latest Free Cash Flow value dynamically
        latest_date = cashflow_df.columns[0]  # Get the last column (latest date)
        row_data['CF'] = cashflow_df.loc['Free Cash Flow', latest_date]
        
        url=get_link2(ticker_symbol[:-3]) # Exclude ".KL for Bursa Marketplace Search Function"
        driver.get(url)
        content = driver.page_source
        soup = bs(content)
        
        time.sleep(5)
        
        try:
            stock_PE = driver.find_element(By.XPATH, "//div[text()='P/E']/following-sibling::div")
            row_data['P/E'] = stock_PE.text
            stock_ROE = driver.find_element(By.XPATH, "//div[text()='ROE']/following-sibling::div")
            row_data['ROE'] = stock_ROE.text
            stock_EPS = driver.find_element(By.XPATH, "//div[text()='EPS']/following-sibling::div")
            row_data['EPS'] = stock_EPS.text
        except:
             print('stock code :'+s+' cannot scrape values')

        # Append the data as a row to the results DataFrame
        results_df = pd.concat([results_df, pd.DataFrame([row_data])], ignore_index=True)
        

    except Exception as e:
        print(f"Error fetching data for {ticker_symbol}: {str(e)}")
# Out:
# {'Ticker': '0800EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0800EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '2771.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 2771.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '3484.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 3484.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0400GB.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0400GB.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '5835.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 5835.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '03055.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': 0.0}
# Error fetching data for 03055.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0820EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0820EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '7192.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -0.29802}
# Error fetching data for 7192.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '5108.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 5108.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0401GA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0401GA.KL: index 0 is out of bounds for axis 0 with size 0
# Error fetching data for 8931.KL: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/8931.KL?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# {'Ticker': '0835EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0835EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0834EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0834EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '6645.KL', 'dividendYield': 1.9855, 'payoutRatio': 0.0, 'operatingMargins': 0.78263}
# Error fetching data for 6645.KL: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="url"]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6963F7892+54818]
# 	(No symbol) [0x00007FF696366AC2]
# 	(No symbol) [0x00007FF69621DA3B]
# 	(No symbol) [0x00007FF69625E4FC]
# 	(No symbol) [0x00007FF69625E67C]
# 	(No symbol) [0x00007FF696299627]
# 	(No symbol) [0x00007FF69627EAEF]
# 	(No symbol) [0x00007FF6962975A2]
# 	(No symbol) [0x00007FF69627E883]
# 	(No symbol) [0x00007FF696253691]
# 	(No symbol) [0x00007FF6962548D4]
# 	GetHandleVerifier [0x00007FF69675B992+3610402]
# 	GetHandleVerifier [0x00007FF6967B1860+3962352]
# 	GetHandleVerifier [0x00007FF6967A9D4F+3930847]
# 	GetHandleVerifier [0x00007FF696493646+693206]
# 	(No symbol) [0x00007FF696371628]
# 	(No symbol) [0x00007FF69636D934]
# 	(No symbol) [0x00007FF69636DA62]
# 	(No symbol) [0x00007FF69635E113]
# 	BaseThreadInitThunk [0x00007FFD44FD7344+20]
# 	RtlUserThreadStart [0x00007FFD46F226B1+33]
#
# {'Ticker': '0821EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0821EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0827EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0827EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0824EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0824EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0825EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0825EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0822EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0822EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0823EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0823EA.KL: index 0 is out of bounds for axis 0 with size 0
# Error fetching data for 5270.KL: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/5270.KL?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# {'Ticker': '7158.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 7158.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '5268.KL', 'dividendYield': None, 'payoutRatio': 0.0, 'operatingMargins': -1.6310099}
# Error fetching data for 5268.KL: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="url"]"}
#   (Session info: chrome=117.0.5938.92); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6963F7892+54818]
# 	(No symbol) [0x00007FF696366AC2]
# 	(No symbol) [0x00007FF69621DA3B]
# 	(No symbol) [0x00007FF69625E4FC]
# 	(No symbol) [0x00007FF69625E67C]
# 	(No symbol) [0x00007FF696299627]
# 	(No symbol) [0x00007FF69627EAEF]
# 	(No symbol) [0x00007FF6962975A2]
# 	(No symbol) [0x00007FF69627E883]
# 	(No symbol) [0x00007FF696253691]
# 	(No symbol) [0x00007FF6962548D4]
# 	GetHandleVerifier [0x00007FF69675B992+3610402]
# 	GetHandleVerifier [0x00007FF6967B1860+3962352]
# 	GetHandleVerifier [0x00007FF6967A9D4F+3930847]
# 	GetHandleVerifier [0x00007FF696493646+693206]
# 	(No symbol) [0x00007FF696371628]
# 	(No symbol) [0x00007FF69636D934]
# 	(No symbol) [0x00007FF69636DA62]
# 	(No symbol) [0x00007FF69635E113]
# 	BaseThreadInitThunk [0x00007FFD44FD7344+20]
# 	RtlUserThreadStart [0x00007FFD46F226B1+33]
#
# {'Ticker': '0836EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0836EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0833EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0833EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0832EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0832EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0837EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0837EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0831EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0831EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0830EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0830EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0829EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0829EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0829EB.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0829EB.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0828EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0828EA.KL: index 0 is out of bounds for axis 0 with size 0
# {'Ticker': '0838EA.KL', 'dividendYield': None, 'payoutRatio': None, 'operatingMargins': None}
# Error fetching data for 0838EA.KL: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ## Therefore, the resulting dataframe can be proceed excluding these error Tickers
# The tickers that failed to retrieve the values are due to various reasons that cannot be addressed at this current time:
# 1) The search engine in Bursa Malaysia did not manage to render the link to the ticker from its search function. This is probably due to the company recently being delisted in Bursa Marketplace sometime after the list of stocks was released.
#
#
# 2) Unable to resolve the HTML element in Bursa Marketplace ticker page. One or more elements that displays the required ratios could not be found on some symbols after loading its respective link in Bursa Marketplace. These symbols are excluded for incomplete information of potentially healthy companies.
#
#
# 2) Could not resolve cash flow statement from Yahoo Finance. Free cash flow is an important metric that was calculated by Yahoo Finance through their cash flow reports. These symbols are excluded for incomplete information for filtration of potentially healthy companies.

# %%
new_list
# Out:
# ['5082.KL',
#  '6602.KL',
#  '0400GB.KL',
#  '2143.KL',
#  '0116.KL',
#  '5020.KL',
#  '9113.KL',
#  '8931.KL',
#  '7096.KL',
#  '7153.KL',
#  '8303.KL',
#  '5001.KL',
#  '0035.KL',
#  '7055.KL',
#  '0260.KL',
#  '5270.KL',
#  '5285.KL',
#  '5140.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL',
#  '8931.KL',
#  '5270.KL']

# %% [markdown]
# ## Successfully retrieved the Dividend & Foundational Ratios of the list of Stock Symbols. With the resulting Dataframe, the retrieved data are saved in a CSV file as a checkpoint

# %%
# Save the results to a CSV file
results_df.to_csv('stock_info.csv', index=False)

# %%
df2 = pd.read_csv('exports/stock_info.csv')
df2
# Out:
#        Ticker  dividendYield  payoutRatio  operatingMargins           CF  \
# 0     5250.KL         0.0271       1.0385           0.04819  353993000.0
# 1     7167.KL         0.0465       0.4039           0.08492 -143040391.0
# 2     7086.KL            NaN       0.0000           0.04338     810389.0
# 3     5198.KL            NaN       0.0000           0.01950  -45692900.0
# 4    03028.KL         0.0566      99.0000          -0.00005   -5502239.0
# ..        ...            ...          ...               ...          ...
# 975   7020.KL            NaN       0.0000          -0.00534    3660971.0
# 976   7014.KL            NaN       0.0000           0.08203   -8095000.0
# 977   3158.KL            NaN       0.0000           0.23088   24588648.0
# 978   7066.KL            NaN       0.0000          -0.01471  -48212179.0
# 979   5159.KL         0.0425       0.2354           0.19365   29487000.0
#
#         P/E      ROE     EPS
# 0     38.19   51.103   0.060
# 1     12.02    8.475   0.109
# 2    108.11    0.674   0.000
# 3         -   -3.447  -0.012
# 4         -   -0.253   0.000
# ..      ...      ...     ...
# 975       -  -11.211  -0.013
# 976    7.74    3.636   0.033
# 977       -   -2.587  -0.005
# 978       -   -8.419  -0.060
# 979    6.50   13.078   0.240
#
# [980 rows x 8 columns]

# %% [markdown]
# # Part II: Data Cleaning & Symbol Selection
# Now that the ratios are retrieved for the stock symbols, additional preprocessing is carried out to prepare the data before selecting the potentially healthy and growing companies.
#
# ## Imputing Missing or "-" values
# Some of these retrieved values are displayed as "-" in Bursa Marketplace or Yahoo Finance which indicate incomplete information. These values are imputed as 0.

# %%
import pandas as pd

# Impute missing values in 'dividendYield' and 'payoutRatio' columns with 0
df2['dividendYield'].fillna(0, inplace=True)
df2['payoutRatio'].fillna(0, inplace=True)
df2['operatingMargins'].fillna(0, inplace=True)
# Impute dashes in 'P/E' column with 0
df2['P/E'].replace('-', 0, inplace=True)
df2['ROE'].replace('-', 0, inplace=True)
df2['EPS'].replace('-', 0, inplace=True)

# Save the DataFrame back to a CSV file
df2.to_csv('exports/imputed_file.csv', index=False)

# %% [markdown]
# ## Converting Data Types
# The data types are converted from string to float to carry out conditional processes to assign classes.

# %%
# Convert specific columns to float
columns_to_convert = ['dividendYield', 'payoutRatio', 'operatingMargins', 'CF', 'P/E', 'ROE', 'EPS']

for column in columns_to_convert:
    df2[column] = pd.to_numeric(df2[column], errors='coerce').fillna(0)

# %%
# # Define the filtering conditions
# conditions = (df2['dividendYield'] >= 0.02) & \
#               (df2['payoutRatio'].between(0.2, 0.75)) & \
#               (df2['operatingMargins'] >= 0.1) & \
#               (df2['CF'] >= 0) & \
#               (df2['P/E'] <= 10) & \
#               (df2['ROE'] >= 20) & \
#               (df2['EPS'] >= 0.1)

# # Apply the conditions to filter the DataFrame
# filtered_df = df2[conditions]

# # Save the filtered DataFrame to a new CSV file
# filtered_df.to_csv('filtered_csv_file.csv', index=False)  # Replace 'filtered_csv_file.csv' with the desired output file path

# %% [markdown]
# ## Assigning Classes to Stock Symbols based on Ratio Values
#
# Now we can proceed to categorize the stock symbols in classes based on values of their retrieved ratios. Firstly, we also have to categorize the ratios based on its relation towards Dividends, or the company's Foundational Health:
#
# Foundation Ratios: Operating Margins, Price to Earnings, Return of Equity, Earnings Per Share and Free Cash Flow
# Dividend Ratios: Dividend Yield, Payout Ratio
#
#
# The classes defined are Class A, B, C, D which are assigned based on the conditions on the above categories:
#
# 1) Class A - Foundation and Dividend meets requirements
#
#
# 2) Class B - Foundation meets requirements, Dividend does not meet requirements
#
#
# 3) Class C - Foundation does not meet requirements, Dividend meet requirements
#
#
# 4) Class D - Foundation and Dividend do not meet requirements

# %%
import pandas as pd
import numpy as np

# Define the DataFrame 'df2' with your data

# Define the filtering conditions
dividend_condition = (df2['dividendYield'] >= 0.02) & (df2['payoutRatio'].between(0.1, 0.75))
foundation_condition = (df2['operatingMargins'] >= 0.1) & (df2['CF'] >= 0) & (df2['P/E'] <= 10) & (df2['ROE'] >= 20) & (df2['EPS'] >= 0.1)

# Define the choices and values for the 'class' column
choices = [
    np.select([dividend_condition, foundation_condition], [1, 1]),  # Class A
    np.select([dividend_condition, foundation_condition], [0, 1]),  # Class B
    np.select([dividend_condition, foundation_condition], [1, 0]),  # Class C
    np.select([dividend_condition, foundation_condition], [0, 0])   # Class D
]

# Create the 'class' column based on the choices
df2['class'] = np.select([dividend_condition & foundation_condition, foundation_condition, dividend_condition], ['A', 'B', 'C'], default='D')

# Save the DataFrame to a new CSV file
df2.to_csv('stock_class.csv', index=False)  # Replace 'output_csv_file.csv' with the desired output file path

# %% [markdown]
# ## Selecting the companies that have good investment potential
# With the approach stated above, we can identify which companies are performing well based on our investment requirements as well as whether or not they provide dividends. Based on the foundation and dividend, our strategy will favor companies that fall into Classes A or B.

# %%
import pandas as pd

# Load the filtered DataFrame (assuming you already have the DataFrame with the "class" column)
df = pd.read_csv('stock_class.csv')  # Replace 'output_csv_file.csv' with the path to your filtered CSV file

# Define the condition to filter for Class A and Class B
class_condition = (df['class'] == 'A')

# Apply the condition to filter the DataFrame
filtered_df = df[class_condition]

# Save the filtered DataFrame to a new CSV file
filtered_df.to_csv('exports/filtered_class_a_b.csv', index=False)  # Replace 'filtered_class_a_b.csv' with the desired output file path
